# %%
import os

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Malay'

# %%
pwd
# Out:
# 'C:\\Users\\Malay'

# %% [markdown]
# # Loding and Understanding the data

# %% [markdown]
# ## We load gender_submission to understand testing accuracy

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Malay\OneDrive\Desktop\Predective Analytics\Datasets\train - train.csv")
# Loading testing data
x_test = pd.read_csv(r"C:\Users\Malay\OneDrive\Desktop\Predective Analytics\Datasets\test - test.csv")
y_test = pd.read_csv(r"C:\Users\Malay\OneDrive\Desktop\Predective Analytics\Datasets\gender_submission - gender_submission.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
y_test
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
x_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
passengerId = x_test['PassengerId']

# %%
passengerId.head()
# Out:
# 0    892
# 1    893
# 2    894
# 3    895
# 4    896
# Name: PassengerId, dtype: int64

# %%
print('x_train')
df.info()
print('-'*70)
print('x_test')
x_test.info()
# Out:
# x_train
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ----------------------------------------------------------------------
# x_test
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
x_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
y_test.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

df['Survived'].value_counts().plot.pie(
    explode=[0,0.1],
    autopct='%1.1f%%',
    ax=ax[0],
    shadow=True
)

ax[0].set_title('Survived')

ax[0].set_ylabel('')

sns.countplot(x='Survived',
              data=df,
              ax=ax[1]
             )

ax[1].bar_label(ax[1].containers[0])

ax[1].set_title('Survived')

plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize=(18,6))
sns.barplot(data=df,x='Pclass', y = 'Survived', hue='Sex', ax=ax[0])
ax[0].set_title('Survival rate by Sex & Class')
ax[0].set_title('Mean Survival Rate')
sns.histplot(data = df, x='Age', hue='Survived', kde=True, bins=30, element='step', ax=ax[1])
ax[1].set_title('Age Distribution By Survival')
plt.tight_layout()
plt.show()

# %% [markdown]
# # DATA WRANGLING

# %%
df['Initial']=0
for i in df.Name:
    df['Initial']=df.Name.str.extract('([A-Za-z]+)\.') #Lets us extract Salutations

# %%
x_test['Initial']=0
for i in x_test.Name:
    x_test['Initial']=x_test.Name.str.extract('([A-Za-z]+)\.') #Lets us extract Salutations

# %%
df['Initial'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
x_test['Initial'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Col', 'Rev', 'Dr', 'Dona'],
#       dtype=object)

# %%
#Checking the Initials
pd.crosstab(df.Initial,df.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_23c3d_row0_col0, #T_23c3d_row0_col1, #T_23c3d_row0_col3, #T_23c3d_row0_col4, #T_23c3d_row0_col5, #T_23c3d_row0_col7, #T_23c3d_row0_col8, #T_23c3d_row0_col12, #T_23c3d_row0_col15, #T_23c3d_row0_col16, #T_23c3d_row1_col2, #T_23c3d_row1_col6, #T_23c3d_row1_col9, #T_23c3d_row1_col10, #T_23c3d_row1_col11, #T_23c3d_row1_col13, #T_23c3d_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_23c3d_row0_col2, #T_23c3d_row0_col6, #T_23c3d_row0_col9, #T_23c3d_row0_col10, #T_23c3d_row0_col11, #T_23c3d_row0_col13, #T_23c3d_row0_col14, #T_23c3d_row1_col0, #T_23c3d_row1_col1, #T_23c3d_row1_col3, #T_23c3d_row1_col4, #T_23c3d_row1_col5, #T_23c3d_row1_col7, #T_23c3d_row1_col8, #T_23c3d_row1_col12, #T_23c3d_row1_col15, #T_23c3d_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_23c3d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_23c3d_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_23c3d_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_23c3d_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_23c3d_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_23c3d_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_23c3d_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_23c3d_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_23c3d_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_23c3d_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_23c3d_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_23c3d_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_23c3d_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_23c3d_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_23c3d_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_23c3d_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_23c3d_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_23c3d_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23c3d_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_23c3d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_23c3d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_23c3d_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_23c3d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_23c3d_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_23c3d_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_23c3d_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_23c3d_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_23c3d_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_23c3d_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_23c3d_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_23c3d_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_23c3d_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_23c3d_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_23c3d_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_23c3d_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_23c3d_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_23c3d_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_23c3d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_23c3d_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_23c3d_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_23c3d_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_23c3d_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_23c3d_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_23c3d_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_23c3d_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_23c3d_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_23c3d_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_23c3d_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_23c3d_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_23c3d_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_23c3d_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_23c3d_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_23c3d_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_23c3d_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)
df['Pclass'].replace([1,2,3],['first','second','third'],inplace=True)
x_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr','Mrs'],inplace=True)
x_test['Pclass'].replace([1,2,3],['first','second','third'],inplace=True)

# %%
#Checking Initials with the same sex
pd.crosstab(df.Initial,df.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_75f6f_row0_col0, #T_75f6f_row0_col2, #T_75f6f_row0_col4, #T_75f6f_row1_col1, #T_75f6f_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_75f6f_row0_col1, #T_75f6f_row0_col3, #T_75f6f_row1_col0, #T_75f6f_row1_col2, #T_75f6f_row1_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75f6f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_75f6f_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_75f6f_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_75f6f_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_75f6f_level0_col3" class="col_heading level0 col3" >Mrs</th>
#       <th id="T_75f6f_level0_col4" class="col_heading level0 col4" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75f6f_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_75f6f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_75f6f_row0_col1" class="data row0 col1" >186</td>
#       <td id="T_75f6f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_75f6f_row0_col3" class="data row0 col3" >127</td>
#       <td id="T_75f6f_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75f6f_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_75f6f_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_75f6f_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_75f6f_row1_col2" class="data row1 col2" >528</td>
#       <td id="T_75f6f_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_75f6f_row1_col4" class="data row1 col4" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(x_test.Initial,x_test.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_407d8_row0_col0, #T_407d8_row0_col2, #T_407d8_row0_col4, #T_407d8_row1_col1, #T_407d8_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_407d8_row0_col1, #T_407d8_row0_col3, #T_407d8_row1_col0, #T_407d8_row1_col2, #T_407d8_row1_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_407d8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_407d8_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_407d8_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_407d8_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_407d8_level0_col3" class="col_heading level0 col3" >Mrs</th>
#       <th id="T_407d8_level0_col4" class="col_heading level0 col4" >Other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_407d8_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_407d8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_407d8_row0_col1" class="data row0 col1" >79</td>
#       <td id="T_407d8_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_407d8_row0_col3" class="data row0 col3" >73</td>
#       <td id="T_407d8_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_407d8_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_407d8_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_407d8_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_407d8_row1_col2" class="data row1 col2" >241</td>
#       <td id="T_407d8_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_407d8_row1_col4" class="data row1 col4" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.Initial.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
sns.catplot(x='Pclass', y='Survived', col='Initial', data=df, kind='point', height=4, aspect= 0.9)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived VS Sex')
sns.countplot(x='Sex',hue='Survived',data=df,ax=ax[1])
ax[1].set_title('Sex: Survived VS Deaad')
plt.show()

# %%
df.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
x_test.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     7.406471
# Miss      21.774844
# Mr        32.114130
# Mrs       38.904762
# Other     42.750000
# Name: Age, dtype: float64

# %%
df.loc[(df.Age.isnull())&(df.Initial=='Master'),'Age']=5
df.loc[(df.Age.isnull())&(df.Initial=='Miss'),'Age']=22
df.loc[(df.Age.isnull())&(df.Initial=='Mr'),'Age']=33
df.loc[(df.Age.isnull())&(df.Initial=='Mrs'),'Age']=36
df.loc[(df.Age.isnull())&(df.Initial=='Other'),'Age']=46

# %%
x_test.loc[(x_test.Age.isnull())&(df.Initial=='Master'),'Age']=5
x_test.loc[(x_test.Age.isnull())&(df.Initial=='Miss'),'Age']=22
x_test.loc[(x_test.Age.isnull())&(df.Initial=='Mr'),'Age']=33
x_test.loc[(x_test.Age.isnull())&(df.Initial=='Mrs'),'Age']=36
x_test.loc[(x_test.Age.isnull())&(df.Initial=='Other'),'Age']=46

# %%
df.Initial.isnull().any()
# Out:
# np.False_

# %%
x_test.Initial.isnull().any()
# Out:
# np.False_

# %%
print('x_train')
df.info()
print('-'*70)
print('x_test')
x_test.info()
# Out:
# x_train
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Initial      891 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 90.6+ KB
# ----------------------------------------------------------------------
# x_test
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    object
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
#  11  Initial      418 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 39.3+ KB

# %%
pd.crosstab([df.Embarked,df.Pclass],[df.Sex,df.Survived],margins=True).style.background_gradient(cmap="summer_r")
# Out:
# <style type="text/css">
# #T_140d7_row0_col0, #T_140d7_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_140d7_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_140d7_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_140d7_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_140d7_row0_col4, #T_140d7_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_140d7_row1_col0, #T_140d7_row3_col0, #T_140d7_row3_col1, #T_140d7_row3_col2, #T_140d7_row3_col3, #T_140d7_row3_col4, #T_140d7_row4_col0, #T_140d7_row4_col2, #T_140d7_row4_col3, #T_140d7_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_140d7_row1_col1, #T_140d7_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_140d7_row1_col3, #T_140d7_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_140d7_row2_col0, #T_140d7_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_140d7_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_140d7_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_140d7_row2_col4, #T_140d7_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_140d7_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_140d7_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_140d7_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_140d7_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_140d7_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_140d7_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_140d7_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_140d7_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_140d7_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_140d7_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_140d7_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_140d7_row7_col3, #T_140d7_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_140d7_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_140d7_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_140d7_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_140d7_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_140d7_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_140d7_row9_col0, #T_140d7_row9_col1, #T_140d7_row9_col2, #T_140d7_row9_col3, #T_140d7_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_140d7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_140d7_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_140d7_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_140d7_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_140d7_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_140d7_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_140d7_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_140d7_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_140d7_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_140d7_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_140d7_level1_row0" class="row_heading level1 row0" >first</th>
#       <td id="T_140d7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_140d7_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_140d7_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_140d7_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_140d7_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level1_row1" class="row_heading level1 row1" >second</th>
#       <td id="T_140d7_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_140d7_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_140d7_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_140d7_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_140d7_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level1_row2" class="row_heading level1 row2" >third</th>
#       <td id="T_140d7_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_140d7_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_140d7_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_140d7_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_140d7_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_140d7_level1_row3" class="row_heading level1 row3" >first</th>
#       <td id="T_140d7_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_140d7_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_140d7_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_140d7_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_140d7_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level1_row4" class="row_heading level1 row4" >second</th>
#       <td id="T_140d7_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_140d7_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_140d7_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_140d7_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_140d7_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level1_row5" class="row_heading level1 row5" >third</th>
#       <td id="T_140d7_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_140d7_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_140d7_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_140d7_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_140d7_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_140d7_level1_row6" class="row_heading level1 row6" >first</th>
#       <td id="T_140d7_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_140d7_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_140d7_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_140d7_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_140d7_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level1_row7" class="row_heading level1 row7" >second</th>
#       <td id="T_140d7_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_140d7_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_140d7_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_140d7_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_140d7_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level1_row8" class="row_heading level1 row8" >third</th>
#       <td id="T_140d7_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_140d7_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_140d7_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_140d7_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_140d7_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_140d7_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_140d7_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_140d7_row9_col0" c

# %%
df.loc[(df.Embarked.isnull())]
# Out:
#      PassengerId  Survived Pclass                                       Name  \
# 61            62         1  first                        Icard, Miss. Amelie
# 829          830         1  first  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Initial
# 61   female  38.0      0      0  113572  80.0   B28      NaN    Miss
# 829  female  62.0      0      0  113572  80.0   B28      NaN     Mrs

# %%
x_test.loc[(x_test.Embarked.isnull())]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Initial]
# Index: []

# %%
df["Embarked"].fillna("S", inplace = True)
x_test["Embarked"].fillna("S", inplace = True)

# %% [markdown]
# ## CREATING A NEW FEATURE BY APPENDING 'Parch' & 'SibSp'

# %%
df['FamilySize'] = df['Parch'] + df['SibSp']
x_test['FamilySize'] = x_test['Parch'] + x_test['SibSp']

# %% [markdown]
# ## DATA CLEANING

# %%
data=df.drop(['PassengerId','Name','Cabin','Ticket','Parch','SibSp'],axis=1,)
x_test=x_test.drop(['PassengerId','Name','Cabin','Ticket','Parch','SibSp'],axis=1,)

# %%
data.head()
# Out:
#    Survived Pclass     Sex   Age     Fare Embarked Initial  FamilySize
# 0         0  third    male  22.0   7.2500        S      Mr           1
# 1         1  first  female  38.0  71.2833        C     Mrs           1
# 2         1  third  female  26.0   7.9250        S    Miss           0
# 3         1  first  female  35.0  53.1000        S     Mrs           1
# 4         0  third    male  35.0   8.0500        S      Mr           0

# %%
data.FamilySize.unique()
# Out:
# array([ 1,  0,  4,  2,  6,  5,  3,  7, 10])

# %%
data.FamilySize.value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style type="text/css">
# #T_5e275_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5e275_row1_col0 {
#   background-color: #4aa466;
#   color: #f1f1f1;
# }
# #T_5e275_row2_col0 {
#   background-color: #2e9666;
#   color: #f1f1f1;
# }
# #T_5e275_row3_col0 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_5e275_row4_col0 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_5e275_row5_col0 {
#   background-color: #048266;
#   color: #f1f1f1;
# }
# #T_5e275_row6_col0 {
#   background-color: #028066;
#   color: #f1f1f1;
# }
# #T_5e275_row7_col0, #T_5e275_row8_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5e275">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e275_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FamilySize</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e275_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e275_row0_col0" class="data row0 col0" >537</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e275_row1_col0" class="data row1 col0" >161</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e275_row2_col0" class="data row2 col0" >102</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e275_row3_col0" class="data row3 col0" >29</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_5e275_row4_col0" class="data row4 col0" >22</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_5e275_row5_col0" class="data row5 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e275_row6_col0" class="data row6 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_5e275_row7_col0" class="data row7 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5e275_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_5e275_row8_col0" class="data row8 col0" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
z = float('inf')
signoid = 1 / (1 + np.exp(z))
print(signoid)
# Out:
# 0.0

# %%
# %matplotlib inline
from __future__ import division

import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def grad_sigmoid(x):
    return sigmoid(x) * (1 - sigmoid(x))


X = np.arange(-10, 10, 0.1)

fig = plt.figure(figsize=(8, 6))

plt.plot(X, sigmoid(X), label='sigmoid', c='blue', linewidth=3)

plt.plot(
    X,
    grad_sigmoid(X),
    label='derivative of sigmoid',
    c='green',
    linewidth=3
)

plt.legend(loc='upper left')

plt.xlabel('X')
plt.grid(True)

plt.ylim([-0.5, 1.5])

plt.ylabel('output')
plt.title('Sigmoid')

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

plt.show()

# %%
class TreeNode:
    def __init__(self, left = None, right = None):
        self.left = left
        self.right = right

relationship_status = TreeNode("No", "Yes")
print (relationship_status)
print (relationship_status.left)
print (relationship_status.right)

age = TreeNode("below 18 years", "18 years or above")
platform = TreeNode(age, relationship_status)

print(platform, ":", platform.left, platform.right)
print(platform.left, ":", platform.left.left, platform.left.right)
print(platform.right, ":", platform.right.left, platform.right.right)
# Out:
# <__main__.TreeNode object at 0x0000011BE13116A0>
# No
# Yes
# <__main__.TreeNode object at 0x0000011BE2353ED0> : <__main__.TreeNode object at 0x0000011BE2353D90> <__main__.TreeNode object at 0x0000011BE13116A0>
# <__main__.TreeNode object at 0x0000011BE2353D90> : below 18 years 18 years or above
# <__main__.TreeNode object at 0x0000011BE13116A0> : No Yes

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler

# -------------------------------------------------------
# KNN from scratch
# -------------------------------------------------------
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

def knn_predict_class(X_train, y_train, x_query, k):
    distances = [(euclidean_distance(x_query, x_i), y_i) for x_i, y_i in zip(X_train, y_train)]
    distances.sort(key=lambda t: t[0])
    k_nearest_labels = [label for _, label in distances[:k]]
    return max(set(k_nearest_labels), key=k_nearest_labels.count)

def knn_predict_reg(X_train, y_train, x_query, k):
    distances = [(euclidean_distance(x_query, x_i), y_i) for x_i, y_i in zip(X_train, y_train)]
    distances.sort(key=lambda t: t[0])
    return np.mean([v for _, v in distances[:k]])

# -------------------------------------------------------
# Visualise KNN decision boundary for k=1,3,9,15
# -------------------------------------------------------
np.random.seed(42)
X, y = make_classification(n_samples=200, n_features=2, n_informative=2,
                            n_redundant=0, n_clusters_per_class=1,
                            class_sep=1.2, random_state=42)
scaler = StandardScaler()
X_s = scaler.fit_transform(X)

K_vals = [1, 3, 9, 15]
fig, axes = plt.subplots(1, 4, figsize=(16, 4))
h = 0.04
xx, yy = np.meshgrid(np.arange(-3, 3, h), np.arange(-3, 3, h))
grid = np.c_[xx.ravel(), yy.ravel()]

for ax, k in zip(axes, K_vals):
    # Vectorised prediction on grid (using from-scratch for pedagogy)
    dists = np.linalg.norm(X_s[:, None, :] - grid[None, :, :], axis=2)  # (n_train, n_grid)
    nn_idx = np.argsort(dists, axis=0)[:k]                               # (k, n_grid)
    votes = y[nn_idx]                                                      # (k, n_grid)
    Z = np.array([np.bincount(votes[:, i], minlength=2).argmax() for i in range(len(grid))])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.25)
    ax.scatter(X_s[:,0], X_s[:,1], c=y, cmap=plt.cm.coolwarm, edgecolors='k', s=20)
    ax.set_title(f'k = {k}')
    ax.set_xlabel('x1'); ax.set_ylabel('x2')
    ax.set_xlim(-3, 3); ax.set_ylim(-3, 3)

plt.suptitle('KNN Decision Boundary vs K (from scratch, Euclidean)', fontsize=11)
plt.tight_layout()
plt.show()
print("k=1 → highly irregular boundary (low bias, high variance)")
print("k=15 → smoother boundary (higher bias, lower variance)")
# Out:
# k=1 → highly irregular boundary (low bias, high variance)
# k=15 → smoother boundary (higher bias, lower variance)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

np.random.seed(42)
X, y = make_classification(n_samples=400, n_features=2, n_informative=2,
                            n_redundant=0, class_sep=1.0, random_state=42)

k_range = range(1, 31)
cv_scores = []
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for k in k_range:
    pipe = Pipeline([('scaler', StandardScaler()),
                     ('knn', KNeighborsClassifier(n_neighbors=k))])
    sc = cross_val_score(pipe, X, y, cv=kf, scoring='accuracy')
    cv_scores.append(sc.mean())

best_k = k_range[np.argmax(cv_scores)]
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(list(k_range), cv_scores, 'b-o', markersize=4, label='CV accuracy')
ax.axvline(best_k, color='r', linestyle='--', label=f'Best k={best_k}')
ax.axvline(int(np.sqrt(400)), color='gray', linestyle=':', label=f'√n = {int(np.sqrt(400))}')
ax.set_xlabel('K'); ax.set_ylabel('5-fold CV Accuracy')
ax.set_title('Choosing K by Cross-Validation')
ax.legend(); ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()
print(f"Best k = {best_k}  CV accuracy = {max(cv_scores):.4f}")
print(f"Rule-of-thumb k = √400 = {int(np.sqrt(400))}")
# Out:
# Best k = 29  CV accuracy = 0.9475
# Rule-of-thumb k = √400 = 20
